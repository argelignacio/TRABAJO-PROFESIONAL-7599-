# %%
import os
import re

EXPERIMENT_ID = 'e076a030'
BASE_FOLDER = '../results/'
experiment_folders = sorted([folder for folder in os.listdir(BASE_FOLDER) if re.match('.*' + EXPERIMENT_ID, folder)])
experiment_folders
# Out:
# ['2024-06-19 20:33:24_0_e076a030',
#  '2024-06-19 20:33:24_1_e076a030',
#  '2024-06-19 20:33:24_2_e076a030',
#  '2024-06-19 20:33:24_3_e076a030',
#  '2024-06-19 20:33:24_4_e076a030',
#  '2024-06-19 20:33:24_5_e076a030',
#  '2024-06-19 20:33:24_6_e076a030',
#  '2024-06-19 20:33:24_7_e076a030',
#  '2024-06-19 20:33:24_8_e076a030']

# %%
import pandas as pd

df = pd.read_csv(BASE_FOLDER + experiment_folders[0] + '/df_result.csv')
df
# Out:
#    Precision_hdbscan_custom_64  Precision_reduced_hdbscan_custom_64  \
# 0                     0.940299                             0.935484
#
#    Precision_hdbscan_custom_32  Precision_reduced_hdbscan_custom_32  \
# 0                     0.686567                              0.95122
#
#    Precision_hdbscan_custom_16  Precision_reduced_hdbscan_custom_16  \
# 0                     0.925373                             0.920635
#
#    Precision_hdbscan_custom_8  Precision_reduced_hdbscan_custom_8  \
# 0                    0.761194                            0.813559
#
#    Precision_hdbscan_custom_4  Precision_reduced_hdbscan_custom_4  ...  \
# 0                    0.537313                            0.673469  ...
#
#    Precision_hdbscan_umap  Precision_reduced_hdbscan_umap  \
# 0                0.701493                           0.975
#
#    Precision_hdbscan_node2vec  Precision_reduced_hdbscan_node2vec  \
# 0                     0.19403                            0.277778
#
#    Precision_kmeans_custom  Precision_reduced_kmeans_custom  \
# 0                 0.716418                              1.0
#
#    Precision_kmeans_node2vec  Precision_reduced_kmeans_node2vec  \
# 0                   0.238806                           0.235294
#
#    Precision_louvain  Precision_reduced_louvain
# 0           0.761194                   0.903846
#
# [1 rows x 22 columns]

# %%
df = pd.concat([
    pd.read_csv(BASE_FOLDER + folder + '/df_result.csv') for folder in experiment_folders
])
df
# Out:
#    Precision_hdbscan_custom_64  Precision_reduced_hdbscan_custom_64  \
# 0                     0.940299                             0.935484
# 0                     0.974684                             0.969697
# 0                     0.967391                             1.000000
# 0                     0.960123                             0.968858
# 0                     0.878963                             0.917266
# 0                     0.817284                             0.852459
# 0                     0.982796                             0.982968
# 0                     0.862103                             0.898196
# 0                     0.254181                             0.047671
#
#    Precision_hdbscan_custom_32  Precision_reduced_hdbscan_custom_32  \
# 0                     0.686567                             0.951220
# 0                     0.936709                             0.927536
# 0                     1.000000                             1.000000
# 0                     0.950920                             0.958904
# 0                     0.798271                             0.887097
# 0                     0.743210                             0.768889
# 0                     0.987097                             0.985401
# 0                     0.915675                             0.945746
# 0                     0.668060                             0.714734
#
#    Precision_hdbscan_custom_16  Precision_reduced_hdbscan_custom_16  \
# 0                     0.925373                             0.920635
# 0                     0.962025                             0.955224
# 0                     0.934783                             0.966667
# 0                     0.966258                             0.972125
# 0                     0.829971                             0.884615
# 0                     0.765432                             0.796537
# 0                     0.976344                             0.974699
# 0                     0.880952                             0.892593
# 0                     0.765886                             0.831655
#
#    Precision_hdbscan_custom_8  Precision_reduced_hdbscan_custom_8  \
# 0                    0.761194                            0.813559
# 0                    0.898734                            0.888889
# 0                    0.630435                            0.538462
# 0                    0.705521                            0.795833
# 0                    0.809798                            0.856604
# 0                    0.074074                            0.074074
# 0                    0.974194                            0.982801
# 0                    0.044643                            0.044643
# 0                    0.221572                            0.045502
#
#    Precision_hdbscan_custom_4  Precision_reduced_hdbscan_custom_4  ...  \
# 0                    0.537313                            0.673469  ...
# 0                    0.708861                            0.800000  ...
# 0                    0.543478                            0.491803  ...
# 0                    0.254601                            0.219512  ...
# 0                    0.175793                            0.175793  ...
# 0                    0.074074                            0.074074  ...
# 0                    0.559140                            0.647925  ...
# 0                    0.277778                            0.328402  ...
# 0                    0.036789                            0.036789  ...
#
#    Precision_hdbscan_umap  Precision_reduced_hdbscan_umap  \
# 0                0.701493                        0.975000
# 0                0.810127                        0.810127
# 0                0.652174                        0.652174
# 0                0.871166                        0.871166
# 0                0.795389                        0.795389
# 0                0.414815                        0.387464
# 0                0.804301                        0.804301
# 0                0.706349                        0.706349
# 0                0.434783                        0.411429
#
#    Precision_hdbscan_node2vec  Precision_reduced_hdbscan_node2vec  \
# 0                    0.194030                            0.277778
# 0                    0.151899                            0.000000
# 0                    0.326087                                 NaN
# 0                    0.116564                            0.112676
# 0                    0.121037                            0.000000
# 0                    0.308642                            0.000000
# 0                    0.053763                            0.044444
# 0                    0.051587                            0.000000
# 0                    0.201505                            0.000000
#
#    Precision_kmeans_custom  Precision_reduced_kmeans_custom  \
# 0                 0.716418                         1.000000
# 0                 0.759494                         0.941176
# 0                 0.836957                         0.765625
# 0                 0.868098                         0.868098
# 0                 0.792507                         0.792507
# 0                 0.637037                         0.637037
# 0                 0.870968                         0.870968
# 0                 0.796627                         0.796627
# 0                 0.628763                         0.628763
#
#    Precision_kmeans_node2vec  Precision_reduced_kmeans_node2vec  \
# 0                   0.238806                           0.235294
# 0                   0.227848                           0.187500
# 0                   0.086957                           0.086957
# 0                   0.073620                           0.073620
# 0                   0.164265                           0.135593
# 0                   0.086420                           0.086420
# 0                   0.030108                           0.030108
# 0                   0.011905                           0.011905
# 0                   0.030100                           0.030100
#
#    Precision_louvain  Precision_reduced_louvain
# 0           0.761194                   0.903846
# 0           0.392405                   0.390625
# 0           0.282609                   0.222222
# 0           0.871166                   0.871166
# 0           0.798271                   0.798271
# 0           0.400000                   0.400000
# 0           0.870968                   0.870968
# 0           0.700397                   0.700397
# 0           0.451505                   0.451505
#
# [9 rows x 22 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#    Precision_hdbscan_custom_64  Precision_reduced_hdbscan_custom_64  \
# 0                     0.940299                             0.935484
# 1                     0.974684                             0.969697
# 2                     0.967391                             1.000000
# 3                     0.960123                             0.968858
# 4                     0.878963                             0.917266
# 5                     0.817284                             0.852459
# 6                     0.982796                             0.982968
# 7                     0.862103                             0.898196
# 8                     0.254181                             0.047671
#
#    Precision_hdbscan_custom_32  Precision_reduced_hdbscan_custom_32  \
# 0                     0.686567                             0.951220
# 1                     0.936709                             0.927536
# 2                     1.000000                             1.000000
# 3                     0.950920                             0.958904
# 4                     0.798271                             0.887097
# 5                     0.743210                             0.768889
# 6                     0.987097                             0.985401
# 7                     0.915675                             0.945746
# 8                     0.668060                             0.714734
#
#    Precision_hdbscan_custom_16  Precision_reduced_hdbscan_custom_16  \
# 0                     0.925373                             0.920635
# 1                     0.962025                             0.955224
# 2                     0.934783                             0.966667
# 3                     0.966258                             0.972125
# 4                     0.829971                             0.884615
# 5                     0.765432                             0.796537
# 6                     0.976344                             0.974699
# 7                     0.880952                             0.892593
# 8                     0.765886                             0.831655
#
#    Precision_hdbscan_custom_8  Precision_reduced_hdbscan_custom_8  \
# 0                    0.761194                            0.813559
# 1                    0.898734                            0.888889
# 2                    0.630435                            0.538462
# 3                    0.705521                            0.795833
# 4                    0.809798                            0.856604
# 5                    0.074074                            0.074074
# 6                    0.974194                            0.982801
# 7                    0.044643                            0.044643
# 8                    0.221572                            0.045502
#
#    Precision_hdbscan_custom_4  Precision_reduced_hdbscan_custom_4  ...  \
# 0                    0.537313                            0.673469  ...
# 1                    0.708861                            0.800000  ...
# 2                    0.543478                            0.491803  ...
# 3                    0.254601                            0.219512  ...
# 4                    0.175793                            0.175793  ...
# 5                    0.074074                            0.074074  ...
# 6                    0.559140                            0.647925  ...
# 7                    0.277778                            0.328402  ...
# 8                    0.036789                            0.036789  ...
#
#    Precision_hdbscan_umap  Precision_reduced_hdbscan_umap  \
# 0                0.701493                        0.975000
# 1                0.810127                        0.810127
# 2                0.652174                        0.652174
# 3                0.871166                        0.871166
# 4                0.795389                        0.795389
# 5                0.414815                        0.387464
# 6                0.804301                        0.804301
# 7                0.706349                        0.706349
# 8                0.434783                        0.411429
#
#    Precision_hdbscan_node2vec  Precision_reduced_hdbscan_node2vec  \
# 0                    0.194030                            0.277778
# 1                    0.151899                            0.000000
# 2                    0.326087                                 NaN
# 3                    0.116564                            0.112676
# 4                    0.121037                            0.000000
# 5                    0.308642                            0.000000
# 6                    0.053763                            0.044444
# 7                    0.051587                            0.000000
# 8                    0.201505                            0.000000
#
#    Precision_kmeans_custom  Precision_reduced_kmeans_custom  \
# 0                 0.716418                         1.000000
# 1                 0.759494                         0.941176
# 2                 0.836957                         0.765625
# 3                 0.868098                         0.868098
# 4                 0.792507                         0.792507
# 5                 0.637037                         0.637037
# 6                 0.870968                         0.870968
# 7                 0.796627                         0.796627
# 8                 0.628763                         0.628763
#
#    Precision_kmeans_node2vec  Precision_reduced_kmeans_node2vec  \
# 0                   0.238806                           0.235294
# 1                   0.227848                           0.187500
# 2                   0.086957                           0.086957
# 3                   0.073620                           0.073620
# 4                   0.164265                           0.135593
# 5                   0.086420                           0.086420
# 6                   0.030108                           0.030108
# 7                   0.011905                           0.011905
# 8                   0.030100                           0.030100
#
#    Precision_louvain  Precision_reduced_louvain
# 0           0.761194                   0.903846
# 1           0.392405                   0.390625
# 2           0.282609                   0.222222
# 3           0.871166                   0.871166
# 4           0.798271                   0.798271
# 5           0.400000                   0.400000
# 6           0.870968                   0.870968
# 7           0.700397                   0.700397
# 8           0.451505                   0.451505
#
# [9 rows x 22 columns]

# %%
df.sort_values(by='Precision_reduced_hdbscan_custom_64', ascending=False)
# Out:
#    Precision_hdbscan_custom_64  Precision_reduced_hdbscan_custom_64  \
# 2                     0.967391                             1.000000
# 6                     0.982796                             0.982968
# 1                     0.974684                             0.969697
# 3                     0.960123                             0.968858
# 0                     0.940299                             0.935484
# 4                     0.878963                             0.917266
# 7                     0.862103                             0.898196
# 5                     0.817284                             0.852459
# 8                     0.254181                             0.047671
#
#    Precision_hdbscan_custom_32  Precision_reduced_hdbscan_custom_32  \
# 2                     1.000000                             1.000000
# 6                     0.987097                             0.985401
# 1                     0.936709                             0.927536
# 3                     0.950920                             0.958904
# 0                     0.686567                             0.951220
# 4                     0.798271                             0.887097
# 7                     0.915675                             0.945746
# 5                     0.743210                             0.768889
# 8                     0.668060                             0.714734
#
#    Precision_hdbscan_custom_16  Precision_reduced_hdbscan_custom_16  \
# 2                     0.934783                             0.966667
# 6                     0.976344                             0.974699
# 1                     0.962025                             0.955224
# 3                     0.966258                             0.972125
# 0                     0.925373                             0.920635
# 4                     0.829971                             0.884615
# 7                     0.880952                             0.892593
# 5                     0.765432                             0.796537
# 8                     0.765886                             0.831655
#
#    Precision_hdbscan_custom_8  Precision_reduced_hdbscan_custom_8  \
# 2                    0.630435                            0.538462
# 6                    0.974194                            0.982801
# 1                    0.898734                            0.888889
# 3                    0.705521                            0.795833
# 0                    0.761194                            0.813559
# 4                    0.809798                            0.856604
# 7                    0.044643                            0.044643
# 5                    0.074074                            0.074074
# 8                    0.221572                            0.045502
#
#    Precision_hdbscan_custom_4  Precision_reduced_hdbscan_custom_4  ...  \
# 2                    0.543478                            0.491803  ...
# 6                    0.559140                            0.647925  ...
# 1                    0.708861                            0.800000  ...
# 3                    0.254601                            0.219512  ...
# 0                    0.537313                            0.673469  ...
# 4                    0.175793                            0.175793  ...
# 7                    0.277778                            0.328402  ...
# 5                    0.074074                            0.074074  ...
# 8                    0.036789                            0.036789  ...
#
#    Precision_hdbscan_umap  Precision_reduced_hdbscan_umap  \
# 2                0.652174                        0.652174
# 6                0.804301                        0.804301
# 1                0.810127                        0.810127
# 3                0.871166                        0.871166
# 0                0.701493                        0.975000
# 4                0.795389                        0.795389
# 7                0.706349                        0.706349
# 5                0.414815                        0.387464
# 8                0.434783                        0.411429
#
#    Precision_hdbscan_node2vec  Precision_reduced_hdbscan_node2vec  \
# 2                    0.326087                            0.000000
# 6                    0.053763                            0.044444
# 1                    0.151899                            0.000000
# 3                    0.116564                            0.112676
# 0                    0.194030                            0.277778
# 4                    0.121037                            0.000000
# 7                    0.051587                            0.000000
# 5                    0.308642                            0.000000
# 8                    0.201505                            0.000000
#
#    Precision_kmeans_custom  Precision_reduced_kmeans_custom  \
# 2                 0.836957                         0.765625
# 6                 0.870968                         0.870968
# 1                 0.759494                         0.941176
# 3                 0.868098                         0.868098
# 0                 0.716418                         1.000000
# 4                 0.792507                         0.792507
# 7                 0.796627                         0.796627
# 5                 0.637037                         0.637037
# 8                 0.628763                         0.628763
#
#    Precision_kmeans_node2vec  Precision_reduced_kmeans_node2vec  \
# 2                   0.086957                           0.086957
# 6                   0.030108                           0.030108
# 1                   0.227848                           0.187500
# 3                   0.073620                           0.073620
# 0                   0.238806                           0.235294
# 4                   0.164265                           0.135593
# 7                   0.011905                           0.011905
# 5                   0.086420                           0.086420
# 8                   0.030100                           0.030100
#
#    Precision_louvain  Precision_reduced_louvain
# 2           0.282609                   0.222222
# 6           0.870968                   0.870968
# 1           0.392405                   0.390625
# 3           0.871166                   0.871166
# 0           0.761194                   0.903846
# 4           0.798271                   0.798271
# 7           0.700397                   0.700397
# 5           0.400000                   0.400000
# 8           0.451505                   0.451505
#
# [9 rows x 22 columns]

# %%
df.fillna(0, inplace=True)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Comparo los reducidos solamente
sample = df[[column for column in df.columns if 'reduced_hdbscan_custom' in column]].sort_values(by='Precision_reduced_hdbscan_custom_64', ascending=False)

# Los nombres salen del config.ini, refieren a:
# Tamaño de Cluster - Intern Proba - Floating Nodes Proportion
# np.array para poder ordenar por una columna y que el gráfico quede más legible
labels = np.array([
    'Small Strong Clean',
    'Medium Mid Clean',
    'Medium Weak Noisy',
    'Medium Strong Clean',
    'Medium Mid Noisy',
    'Medium Weak Noisiest',
    'Big Strong Clean',
    'Big Mid Noisy',
    'Big Weak Noisiest'
])

plt.figure(figsize=(12, 8))
plt.title('Comparación de precisión reducida para distintas task según el tamaño del embedding (HDBSCAN)')
for column in sample.columns:
    plt.plot(sample[column].values)
plt.legend(['Embedding de {}'.format(2**(len(sample.columns) - i)) for i in range(len(sample.columns))])
plt.xticks(ticks=range(len(sample)), labels=labels[sample.index], rotation=45, horizontalalignment='right')
plt.show()

# %%
sample = df[[column for column in df.columns if 'Precision_hdbscan_custom' in column]].sort_values(by='Precision_hdbscan_custom_64', ascending=False)

plt.figure(figsize=(12, 8))
plt.title('Comparación de precisión para distintas task según el tamaño del embedding (HDBSCAN)')
for column in sample.columns:
    plt.plot(sample[column].values)
plt.legend(['Embedding de {}'.format(2**(len(sample.columns) - i)) for i in range(len(sample.columns))])
plt.xticks(ticks=range(len(sample)), labels=labels[sample.index], rotation=45, horizontalalignment='right')
plt.show()

# %%
df.columns
# Out:
# Index(['Precision_hdbscan_custom_64', 'Precision_reduced_hdbscan_custom_64',
#        'Precision_hdbscan_custom_32', 'Precision_reduced_hdbscan_custom_32',
#        'Precision_hdbscan_custom_16', 'Precision_reduced_hdbscan_custom_16',
#        'Precision_hdbscan_custom_8', 'Precision_reduced_hdbscan_custom_8',
#        'Precision_hdbscan_custom_4', 'Precision_reduced_hdbscan_custom_4',
#        'Precision_hdbscan_custom_2', 'Precision_reduced_hdbscan_custom_2',
#        'Precision_hdbscan_umap', 'Precision_reduced_hdbscan_umap',
#        'Precision_hdbscan_node2vec', 'Precision_reduced_hdbscan_node2vec',
#        'Precision_kmeans_custom', 'Precision_reduced_kmeans_custom',
#        'Precision_kmeans_node2vec', 'Precision_reduced_kmeans_node2vec',
#        'Precision_louvain', 'Precision_reduced_louvain'],
#       dtype='object')

# %%
columns = [
    'Precision_reduced_hdbscan_custom_16',
    'Precision_reduced_hdbscan_node2vec',
    'Precision_reduced_kmeans_custom',
    'Precision_reduced_kmeans_node2vec'
]

sample = df[columns].sort_values(by='Precision_reduced_hdbscan_custom_16', ascending=False)

plt.figure(figsize=(12, 8))
plt.title('Comparación de precisión reducida vs Node2Vec')
for column in sample.columns:
    plt.plot(sample[column].values)
plt.legend(['Embedding de 16 + HDBSCAN', 'Node2Vec + HDBSCAN', 'Embedding de 64 + KMeans', 'Node2Vec + KMeans'])
plt.xticks(ticks=range(len(sample)), labels=labels[sample.index], rotation=45, horizontalalignment='right')
plt.show()

# %%
columns = [
    'Precision_reduced_hdbscan_custom_16',
    'Precision_reduced_hdbscan_umap',
    'Precision_reduced_louvain'
]

sample = df[columns].sort_values(by='Precision_reduced_hdbscan_custom_16', ascending=False)

plt.figure(figsize=(12, 8))
plt.title('Comparación de precisión reducida vs Louvain')
for column in sample.columns:
    plt.plot(sample[column].values)
plt.legend(['Embedding de 16 + HDBSCAN', 'Embedding de 64 + UMAP 2D + HDBSCAN', 'Louvain'])
plt.xticks(ticks=range(len(sample)), labels=labels[sample.index], rotation=45, horizontalalignment='right')
plt.show()
